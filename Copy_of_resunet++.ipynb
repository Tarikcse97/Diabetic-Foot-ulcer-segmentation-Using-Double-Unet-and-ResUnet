# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
################################Resunet++############
import os
import numpy as np
import cv2

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

def squeeze_excite_block(inputs, ratio=8):
    init = inputs
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = Multiply()([init, se])
    return x

def stem_block(x, n_filter, strides):
    x_init = x

    ## Conv 1
    x = Conv2D(n_filter, (3, 3), padding="same", strides=strides)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same")(x)

    ## Shortcut
    s  = Conv2D(n_filter, (1, 1), padding="same", strides=strides)(x_init)
    s = BatchNormalization()(s)

    ## Add
    x = Add()([x, s])
    x = squeeze_excite_block(x)
    return x


def resnet_block(x, n_filter, strides=1):
    x_init = x

    ## Conv 1
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same", strides=strides)(x)
    ## Conv 2
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same", strides=1)(x)

    ## Shortcut
    s  = Conv2D(n_filter, (1, 1), padding="same", strides=strides)(x_init)
    s = BatchNormalization()(s)

    ## Add
    x = Add()([x, s])
    x = squeeze_excite_block(x)
    return x

def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y

def attetion_block(g, x):
    """
        g: Output of Parallel Encoder block
        x: Output of Previous Decoder block
    """

    filters = x.shape[-1]

    g_conv = BatchNormalization()(g)
    g_conv = Activation("relu")(g_conv)
    g_conv = Conv2D(filters, (3, 3), padding="same")(g_conv)

    g_pool = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(g_conv)

    x_conv = BatchNormalization()(x)
    x_conv = Activation("relu")(x_conv)
    x_conv = Conv2D(filters, (3, 3), padding="same")(x_conv)

    gc_sum = Add()([g_pool, x_conv])

    gc_conv = BatchNormalization()(gc_sum)
    gc_conv = Activation("relu")(gc_conv)
    gc_conv = Conv2D(filters, (3, 3), padding="same")(gc_conv)

    gc_mul = Multiply()([gc_conv, x])
    return gc_mul

class ResUnetPlusPlus:
    def __init__(self, input_size=256):
        self.input_size = input_size

    def build_model(self):
        n_filters = [16, 32, 64, 128, 256]
        inputs = Input((self.input_size, self.input_size, 3))

        c0 = inputs
        c1 = stem_block(c0, n_filters[0], strides=1)

        ## Encoder
        c2 = resnet_block(c1, n_filters[1], strides=2)
        c3 = resnet_block(c2, n_filters[2], strides=2)
        c4 = resnet_block(c3, n_filters[3], strides=2)

        ## Bridge
        b1 = aspp_block(c4, n_filters[4])

        ## Decoder
        d1 = attetion_block(c3, b1)
        d1 = UpSampling2D((2, 2))(d1)
        d1 = Concatenate()([d1, c3])
        d1 = resnet_block(d1, n_filters[3])

        d2 = attetion_block(c2, d1)
        d2 = UpSampling2D((2, 2))(d2)
        d2 = Concatenate()([d2, c2])
        d2 = resnet_block(d2, n_filters[2])

        d3 = attetion_block(c1, d2)
        d3 = UpSampling2D((2, 2))(d3)
        d3 = Concatenate()([d3, c1])
        d3 = resnet_block(d3, n_filters[1])

        ## output
        outputs = aspp_block(d3, n_filters[0])
        outputs = Conv2D(1, (1, 1), padding="same")(outputs)
        outputs = Activation("sigmoid")(outputs)

        ## Model
        model = Model(inputs, outputs)
        return model
arch = ResUnetPlusPlus(input_size=256)
model = arch.build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 16  64          ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 256, 256, 16  0           ['conv2d_1[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 16)          0           ['add[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 16)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 2)      32          ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 16)     32          ['dense[0][0]']
#
#  multiply (Multiply)            (None, 256, 256, 16  0           ['add[0][0]',
#                                 )                                 'dense_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 16  64         ['multiply[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  4640        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  544         ['multiply[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  9248        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 128, 128, 32  0           ['conv2d_4[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['add_1[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 1, 4)      128         ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 32)     128         ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 128, 32  0           ['add_1[0][0]',
#                                 )                                 'dense_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 32  128        ['multiply_1[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   18496       ['activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 64)   2112        ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 64, 64, 64)   0           ['conv2d_7[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 64)          0           ['add_2[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1, 1, 8)      512         ['reshape_2[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 64)     512         ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 64, 64, 64)   0           ['add_2[0][0]',
#                                                                   'dense_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['multiply_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  73856       ['activation_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  8320        ['multiply_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 128)  0           ['conv2d_10[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 128)         0           ['add_3[0][0]']
#  obalAveragePooling2D)
#
#  reshape_3 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_6 (Dense)                (None, 1, 1, 16)     2048        ['reshape_3[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 128)    2048        ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 32, 32, 128)  0           ['add_3[0][0]',
#                                                                   'dense_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  295168      ['multiply_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  295168      ['multiply_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 256)  295168      ['multiply_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 256)  295168      ['multiply_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 256)  0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['multiply_2[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 256)  65792       ['add_4[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 256)  147712      ['activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_16[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 256)  0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_8[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 256)  1024       ['add_5[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_9[0][0]']
#
#  multiply_4 (Multiply)          (None, 32, 32, 256)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['multiply_4[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 320)  0           ['up_sampling2d[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 320)  1280       ['concatenate[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 320)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 128)  368768      ['activation_10[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_11[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 64, 64, 128)  0           ['conv2d_21[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 128)         0           ['add_6[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1, 1, 16)     2048        ['reshape_4[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 128)    2048        ['dense_8[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['multiply_1[0][0]']
#  ormalization)                  )
#
#  multiply_5 (Multiply)          (None, 64, 64, 128)  0           ['add_6[0][0]',
#                                                                   'dense_9[0][0]']
#
#  activation_12 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 128)  512        ['multiply_5[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  36992       ['activation_12[0][0]']
#                                 8)
#
#  activation_13 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_22[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_13[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 128)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 128)  512        ['add_7[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_14[0][0]']
#
#  multiply_6 (Multiply)          (None, 64, 64, 128)  0           ['conv2d_25[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 12  0          ['multiply_6[0][0]']
#                                 8)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 16  0           ['up_sampling2d_1[0][0]',
#                                 0)                                'multiply_1[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 16  640        ['concatenate_1[0][0]']
#  ormalization)                  0)
#
#  activation_15 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_24[0][0]']
#                                 0)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  92224       ['activation_15[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 64  256        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 64  10304       ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 64  256        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 128, 128, 64  0           ['conv2d_27[0][0]',
#                                 )                                 'batch_normalization_26[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['add_8[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 1, 1, 8)      512         ['reshape_5[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 64)     512         ['dense_10[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 256, 256, 16  64         ['multiply[0][0]']
#  ormalization)                  )
#
#  multiply_7 (Multiply)          (None, 128, 128, 64  0           ['add_8[0][0]',
#                                 )                                 'dense_11[0][0]']
#
#  activation_17 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 64  256        ['multiply_7[0][0]']
#  ormalization)                  )
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 64  9280        ['activation_17[0][0]']
#                                 )
#
#  activation_18 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_29[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 128, 128, 64  0           ['max_pooling2d_2[0][0]',
#                                 )                                 'conv2d_30[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 64  256        ['add_9[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 64  36928       ['activation_19[0][0]']
#                                 )
#
#  multiply_8 (Multiply)          (None, 128, 128, 64  0           ['conv2d_31[0][0]',
#                                 )                                 'multiply_7[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 64  0          ['multiply_8[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 80  0           ['up_sampling2d_2[0][0]',
#                                 )                                 'multiply[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 256, 256, 80  320        ['concatenate_2[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 256, 256, 80  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 32  23072       ['activation_20[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 256, 256, 32  128        ['conv2d_32[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 32  2592        ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 32  9248        ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 256, 256, 32  128        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 256, 256, 32  0           ['conv2d_33[0][0]',
#                                 )                                 'batch_normalization_32[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 32)          0           ['add_10[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 1, 1, 4)      128         ['reshape_6[0][0]']
#
#  dense_13 (Dense)               (None, 1, 1, 32)     128         ['dense_12[0][0]']
#
#  multiply_9 (Multiply)          (None, 256, 256, 32  0           ['add_10[0][0]',
#                                 )                                 'dense_13[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 16  4624        ['multiply_9[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 16  4624        ['multiply_9[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 16  4624        ['multiply_9[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 16  4624        ['multiply_9[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 16  64         ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 16  64         ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 16  64         ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  batch_normalization_36 (BatchN  (None, 256, 256, 16  64         ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_33[0][0]',
#                                 )                                 'batch_normalization_34[0][0]',
#                                                                   'batch_normalization_35[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 16  272         ['add_11[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 1)  17          ['conv2d_39[0][0]']
#
#  activation_22 (Activation)     (None, 256, 256, 1)  0           ['conv2d_40[0][0]']
#
# ==================================================================================================
# Total params: 4,070,385
# Trainable params: 4,062,993
# Non-trainable params: 7,392
# __________________________________________________________________________________________________

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from glob import glob
from tensorflow.keras.losses import binary_crossentropy

#from your_model_file import build_model

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (256, 256))
    x = x / 255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    return x

def preprocess_data1(x, y):
    #size=256
    x = read_image(x)
    #x = cv2.resize(x, (size, size))
    x = x.astype(np.float32) #/ 255.0  # Normalize image
    y = read_mask(y)
    #y = cv2.resize(y, (size, size))
    y = y.astype(np.float32) #/ 255.0  # Normalize mask
    #y = np.expand_dims(y, axis=-1)  # Add channel dimension
    #y = np.concatenate([1 - y, y], axis=-1)  # Convert to binary representation
    return x, y


def load_data1(train_path, valid_path):
    train_x = sorted(glob(os.path.join(train_path, "images", "*.png")))
    train_y = sorted(glob(os.path.join(train_path, "labels", "*.png")))
    valid_x = sorted(glob(os.path.join(valid_path, "images", "*.png")))
    valid_y = sorted(glob(os.path.join(valid_path, "labels", "*.png")))
    train_data = [preprocess_data1(x, y) for x, y in zip(train_x, train_y)]
    valid_data = [preprocess_data1(x, y) for x, y in zip(valid_x, valid_y)]
    return train_data, valid_data

if __name__ == "__main__":
    train_path = "/content/drive/MyDrive/Colab Notebooks/DFU/Foot Ulcer Segmentation Challenge/train"
    valid_path = "/content/drive/MyDrive/Colab Notebooks/DFU/Foot Ulcer Segmentation Challenge/validation"
    model_path = "/content/drive/MyDrive/Colab Notebooks/DFU/Foot Ulcer Segmentation Challenge/model.h5"



##########METRICS######################
    smooth = 1e-15
    def dice_coef(y_true, y_pred):
        y_true = tf.keras.layers.Flatten()(y_true)
        y_pred = tf.keras.layers.Flatten()(y_pred)
        intersection = tf.reduce_sum(y_true * y_pred)
        return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

    def dice_loss(y_true, y_pred):
        return 1.0 - dice_coef(y_true, y_pred)

    def iou(y_true, y_pred):
        def f(y_true, y_pred):
            intersection = (y_true * y_pred).sum()
            union = y_true.sum() + y_pred.sum() - intersection
            x = (intersection + smooth) / (union + smooth)
            x = x.astype(np.float32)
            return x
        return tf.numpy_function(f, [y_true, y_pred], tf.float32)
    def bce_dice_loss(y_true, y_pred):
        return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

    def focal_loss(y_true, y_pred):
        alpha=0.25
        gamma=2
        def focal_loss_with_logits(logits, targets, alpha, gamma, y_pred):
            weight_a = alpha * (1 - y_pred) ** gamma * targets
            weight_b = (1 - alpha) * y_pred ** gamma * (1 - targets)
            return (tf.math.log1p(tf.exp(-tf.abs(logits))) + tf.nn.relu(-logits)) * (weight_a + weight_b) + logits * weight_b

        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        logits = tf.math.log(y_pred / (1 - y_pred))
        loss = focal_loss_with_logits(logits=logits, targets=y_true, alpha=alpha, gamma=gamma, y_pred=y_pred)
        # or reduce_sum and/or axis=-1
        return tf.reduce_mean(loss)
##############
    batch_size = 10
    epochs = 20
    lr = 1e-4
    #shape = (256, 256, 3)

    arch = ResUnetPlusPlus(input_size=256)
    model1 = arch.build_model()
    metrics = [
        iou,dice_coef,focal_loss,dice_loss,bce_dice_loss,
        tf.keras.metrics.Recall(),
        tf.keras.metrics.Precision()
    ]

    train_data, valid_data = load_data1(train_path, valid_path)
    train_x, train_y = zip(*train_data)
    valid_x, valid_y = zip(*valid_data)


    # train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
    # train_dataset = train_dataset.batch(batch_size)
    # valid_dataset = tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
    # valid_dataset = valid_dataset.batch(batch_size)

###2nd
    train_dataset = tf.data.Dataset.from_generator(lambda: train_data,
                                              output_signature=(tf.TensorSpec(shape=(256, 256, 3), dtype=tf.float32),
                                                                tf.TensorSpec(shape=(256, 256, 1), dtype=tf.float32)))

    train_dataset = train_dataset.batch(batch_size)

    valid_dataset = tf.data.Dataset.from_generator(lambda: valid_data,
                                              output_signature=(tf.TensorSpec(shape=(256, 256, 3), dtype=tf.float32),
                                                                tf.TensorSpec(shape=(256, 256, 1), dtype=tf.float32)))


    valid_dataset = valid_dataset.batch(batch_size)

    ###3rd
    #train_dataset = tf.data.Dataset.from_tensor_slices((train_data["train_x"], train_data["train_y"]))
    # train_dataset = train_dataset.map(preprocess_data)
    #train_dataset = train_dataset.batch(batch_size)

    #valid_dataset = tf.data.Dataset.from_tensor_slices((valid_data["valid_x"], valid_data["valid_y"]))
    # valid_dataset = valid_dataset.map(preprocess_data)
    #valid_dataset = valid_dataset.batch(batch_size)



    model1.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    callbacks = [
        ModelCheckpoint(model_path),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=epochs*.3),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=epochs*.3, restore_best_weights=False)
    ]


    train_steps = len(train_x)//batch_size
    valid_steps = len(valid_x)//batch_size
    train_dataset = train_dataset.repeat()
    # if len(train_x) % batch_size != 0:
    #     train_steps += 1
    # if len(valid_x) % batch_size != 0:
    #     valid_steps += 1

# %%
    model1.fit(train_dataset,
        validation_data=valid_dataset,
        epochs=epochs,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks)
# Out:
# Epoch 1/20
# 81/81 [==============================] - 104s 581ms/step - loss: 0.8770 - iou: 0.0672 - dice_coef: 0.1230 - focal_loss: 0.6930 - dice_loss: 0.8770 - bce_dice_loss: 2.8260 - recall: 0.8900 - precision: 0.0662 - val_loss: 0.9826 - val_iou: 0.0088 - val_dice_coef: 0.0174 - val_focal_loss: 0.0076 - val_dice_loss: 0.9826 - val_bce_dice_loss: 1.1111 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/20
# 81/81 [==============================] - 44s 548ms/step - loss: 0.7289 - iou: 0.1606 - dice_coef: 0.2711 - focal_loss: 0.4694 - dice_loss: 0.7289 - bce_dice_loss: 3.1310 - recall: 0.9262 - precision: 0.2066 - val_loss: 0.9881 - val_iou: 0.0060 - val_dice_coef: 0.0119 - val_focal_loss: 0.0125 - val_dice_loss: 0.9881 - val_bce_dice_loss: 1.0574 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/20
# 81/81 [==============================] - 45s 553ms/step - loss: 0.5896 - iou: 0.2651 - dice_coef: 0.4104 - focal_loss: 0.2477 - dice_loss: 0.5896 - bce_dice_loss: 2.6820 - recall: 0.9063 - precision: 0.3523 - val_loss: 0.9931 - val_iou: 0.0034 - val_dice_coef: 0.0069 - val_focal_loss: 0.0160 - val_dice_loss: 0.9931 - val_bce_dice_loss: 1.0635 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/20
# 81/81 [==============================] - 45s 551ms/step - loss: 0.4617 - iou: 0.3772 - dice_coef: 0.5383 - focal_loss: 0.1387 - dice_loss: 0.4617 - bce_dice_loss: 2.0783 - recall: 0.8891 - precision: 0.5018 - val_loss: 0.9962 - val_iou: 0.0019 - val_dice_coef: 0.0038 - val_focal_loss: 0.0184 - val_dice_loss: 0.9962 - val_bce_dice_loss: 1.0731 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/20
# 81/81 [==============================] - 45s 552ms/step - loss: 0.3740 - iou: 0.4651 - dice_coef: 0.6260 - focal_loss: 0.0935 - dice_loss: 0.3740 - bce_dice_loss: 1.6746 - recall: 0.8629 - precision: 0.6009 - val_loss: 0.9080 - val_iou: 0.0500 - val_dice_coef: 0.0920 - val_focal_loss: 0.0251 - val_dice_loss: 0.9080 - val_bce_dice_loss: 1.0343 - val_recall: 0.0596 - val_precision: 0.5567 - lr: 1.0000e-04
# Epoch 6/20
# 81/81 [==============================] - 45s 551ms/step - loss: 0.2988 - iou: 0.5481 - dice_coef: 0.7012 - focal_loss: 0.0624 - dice_loss: 0.2988 - bce_dice_loss: 1.2302 - recall: 0.8510 - precision: 0.7001 - val_loss: 0.8076 - val_iou: 0.1128 - val_dice_coef: 0.1924 - val_focal_loss: 0.0227 - val_dice_loss: 0.8076 - val_bce_dice_loss: 0.9058 - val_recall: 0.1201 - val_precision: 0.8997 - lr: 1.0000e-04
# Epoch 7/20
# 81/81 [==============================] - 45s 552ms/step - loss: 0.2474 - iou: 0.6101 - dice_coef: 0.7526 - focal_loss: 0.0462 - dice_loss: 0.2474 - bce_dice_loss: 0.9470 - recall: 0.8403 - precision: 0.7678 - val_loss: 0.5245 - val_iou: 0.3236 - val_dice_coef: 0.4755 - val_focal_loss: 0.0224 - val_dice_loss: 0.5245 - val_bce_dice_loss: 0.6323 - val_recall: 0.3463 - val_precision: 0.9078 - lr: 1.0000e-04
# Epoch 8/20
# 81/81 [==============================] - 45s 551ms/step - loss: 0.2001 - iou: 0.6715 - dice_coef: 0.7999 - focal_loss: 0.0349 - dice_loss: 0.2001 - bce_dice_loss: 0.7051 - recall: 0.8480 - precision: 0.8231 - val_loss: 0.3048 - val_iou: 0.5385 - val_dice_coef: 0.6952 - val_focal_loss: 0.0457 - val_dice_loss: 0.3048 - val_bce_dice_loss: 0.8074 - val_recall: 0.7073 - val_precision: 0.7394 - lr: 1.0000e-04
# Epoch 9/20
# 81/81 [==============================] - 45s 552ms/step - loss: 0.1720 - iou: 0.7104 - dice_coef: 0.8280 - focal_loss: 0.0294 - dice_loss: 0.1720 - bce_dice_loss: 0.5996 - recall: 0.8540 - precision: 0.8546 - val_loss: 0.3863 - val_iou: 0.4542 - val_dice_coef: 0.6137 - val_focal_loss: 0.0215 - val_dice_loss: 0.3863 - val_bce_dice_loss: 0.5098 - val_recall: 0.4881 - val_precision: 0.9151 - lr: 1.0000e-04
# Epoch 10/20
# 81/81 [==============================] - 47s 580ms/step - loss: 0.1486 - iou: 0.7440 - dice_coef: 0.8514 - focal_loss: 0.0246 - dice_loss: 0.1486 - bce_dice_loss: 0.4787 - recall: 0.8617 - precision: 0.8799 - val_loss: 0.2992 - val_iou: 0.5533 - val_dice_coef: 0.7008 - val_focal_loss: 0.0229 - val_dice_loss: 0.2992 - val_bce_dice_loss: 0.4758 - val_recall: 0.6060 - val_precision: 0.8854 - lr: 1.0000e-04
# Epoch 11/20
# 81/81 [==============================] - 45s 550ms/step - loss: 0.1411 - iou: 0.7550 - dice_coef: 0.8589 - focal_loss: 0.0230 - dice_loss: 0.1411 - bce_dice_loss: 0.4332 - recall: 0.8607 - precision: 0.8893 - val_loss: 0.2311 - val_iou: 0.6314 - val_dice_coef: 0.7689 - val_focal_loss: 0.0315 - val_dice_loss: 0.2311 - val_bce_dice_loss: 0.5057 - val_recall: 0.7597 - val_precision: 0.8203 - lr: 1.0000e-04
# Epoch 12/20
# 81/81 [==============================] - 47s 576ms/step - loss: 0.1279 - iou: 0.7756 - dice_coef: 0.8721 - focal_loss: 0.0203 - dice_loss: 0.1279 - bce_dice_loss: 0.3778 - recall: 0.8660 - precision: 0.9042 - val_loss: 0.2436 - val_iou: 0.6151 - val_dice_coef: 0.7564 - val_focal_loss: 0.0254 - val_dice_loss: 0.2436 - val_bce_dice_loss: 0.4706 - val_recall: 0.6881 - val_precision: 0.8660 - lr: 1.0000e-04
# Epoch 13/20
# 81/81 [==============================] - 45s 550ms/step - loss: 0.1090 - iou: 0.8048 - dice_coef: 0.8910 - focal_loss: 0.0172 - dice_loss: 0.1090 - bce_dice_loss: 0.3007 - recall: 0.8790 - precision: 0.9232 - val_loss: 0.2302 - val_iou: 0.6331 - val_dice_coef: 0.7698 - val_focal_loss: 0.0275 - val_dice_loss: 0.2302 - val_bce_dice_loss: 0.4758 - val_recall: 0.7146 - val_precision: 0.8500 - lr: 1.0000e-04
# Epoch 14/20
# 81/81 [==============================] - 45s 551ms/step - loss: 0.1051 - iou: 0.8111 - dice_coef: 0.8949 - focal_loss: 0.0172 - dice_loss: 0.1051 - bce_dice_loss: 0.2908 - recall: 0.8864 - precision: 0.9228 - val_loss: 0.2434 - val_iou: 0.6182 - val_dice_coef: 0.7566 - val_focal_loss: 0.0280 - val_dice_loss: 0.2434 - val_bce_dice_loss: 0.6567 - val_recall: 0.6832 - val_precision: 0.8611 - lr: 1.0000e-04
# Epoch 15/20
# 81/81 [==============================] - 44s 550ms/step - loss: 0.1049 - iou: 0.8112 - dice_coef: 0.8951 - focal_loss: 0.0172 - dice_loss: 0.1049 - bce_dice_loss: 0.2909 - recall: 0.8844 - precision: 0.9222 - val_loss: 0.2250 - val_iou: 0.6408 - val_dice_coef: 0.7750 - val_focal_loss: 0.0306 - val_dice_loss: 0.2250 - val_bce_dice_loss: 0.5527 - val_recall: 0.7365 - val_precision: 0.8343 - lr: 1.0000e-04
# Epoch 16/20
# 81/81 [==============================] - 45s 552ms/step - loss: 0.1035 - iou: 0.8135 - dice_coef: 0.8965 - focal_loss: 0.0172 - dice_loss: 0.1035 - bce_dice_loss: 0.2817 - recall: 0.8835 - precision: 0.9222 - val_loss: 0.2586 - val_iou: 0.5957 - val_dice_coef: 0.7414 - val_focal_loss: 0.0563 - val_dice_loss: 0.2586 - val_bce_dice_loss: 1.1454 - val_recall: 0.8157 - val_precision: 0.7086 - lr: 1.0000e-04
# Epoch 17/20
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0928 - iou: 0.8309 - dice_coef: 0.9072 - focal_loss: 0.0154 - dice_loss: 0.0928 - bce_dice_loss: 0.2535 - recall: 0.8914 - precision: 0.9333 - val_loss: 0.2327 - val_iou: 0.6287 - val_dice_coef: 0.7673 - val_focal_loss: 0.0404 - val_dice_loss: 0.2327 - val_bce_dice_loss: 0.6841 - val_recall: 0.7664 - val_precision: 0.7786 - lr: 1.0000e-04
# Epoch 18/20
# 81/81 [==============================] - 45s 552ms/step - loss: 0.0828 - iou: 0.8478 - dice_coef: 0.9172 - focal_loss: 0.0136 - dice_loss: 0.0828 - bce_dice_loss: 0.2197 - recall: 0.9016 - precision: 0.9427 - val_loss: 0.2325 - val_iou: 0.6316 - val_dice_coef: 0.7675 - val_focal_loss: 0.0226 - val_dice_loss: 0.2325 - val_bce_dice_loss: 0.4379 - val_recall: 0.6691 - val_precision: 0.9008 - lr: 1.0000e-04
# Epoch 19/20
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0833 - iou: 0.8468 - dice_coef: 0.9167 - focal_loss: 0.0137 - dice_loss: 0.0833 - bce_dice_loss: 0.2249 - recall: 0.8998 - precision: 0.9426 - val_loss: 0.2408 - val_iou: 0.6189 - val_dice_coef: 0.7592 - val_focal_loss: 0.0226 - val_dice_loss: 0.2408 - val_bce_dice_loss: 0.4381 - val_recall: 0.6571 - val_precision: 0.9067 - lr: 1.0000e-04
# Epoch 20/20
# 81/81 [==============================] - 45s 552ms/step - loss: 0.0766 - iou: 0.8581 - dice_coef: 0.9234 - focal_loss: 0.0123 - dice_loss: 0.0766 - bce_dice_loss: 0.1976 - recall: 0.9018 - precision: 0.9512 - val_loss: 0.2244 - val_iou: 0.6415 - val_dice_coef: 0.7756 - val_focal_loss: 0.0244 - val_dice_loss: 0.2244 - val_bce_dice_loss: 0.4722 - val_recall: 0.6960 - val_precision: 0.8870 - lr: 1.0000e-04

# %%
###########
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

def preprocess_test_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (256, 256))
    image = image.astype(np.float32) / 255.0
    return image

def postprocess_mask(mask):
    #mask = np.argmax(mask, axis=-1)

    #############
    mask=cv2.resize(mask,(256,256))
    mask = np.squeeze(mask)
    mask= mask>0.5
    #mask = [mask, mask]
    #mask = np.transpose(mask, (1, 2, 0))

    ############
    mask = mask.astype(np.uint8) * 255
    return mask

def predict_test_images(model, test_image_paths):
    predicted_masks = []
    for image_path in test_image_paths:
        image = preprocess_test_image(image_path)
        mask = model.predict(np.expand_dims(image, axis=0))[0]
        mask = postprocess_mask(mask)
        predicted_masks.append(mask)
    return predicted_masks

# Specify the path to your test images
test_path = "/content/drive/MyDrive/Colab Notebooks/DFU/Foot Ulcer Segmentation Challenge/test"

test_image_paths = sorted(glob(os.path.join(test_path, "images", "*.png")))

# Load the trained model
model_path = "/content/drive/MyDrive/Colab Notebooks/DFU/Foot Ulcer Segmentation Challenge/model.h5"
model = tf.keras.models.load_model(model_path, custom_objects={'dice_loss':dice_loss,'focal_loss':focal_loss,'bce_dice_loss':bce_dice_loss,'dice_coef': dice_coef, 'iou': iou})

# Generate predicted masks for test images
predicted_masks = predict_test_images(model, test_image_paths)

# Display the predicted masks
for i, mask in enumerate(predicted_masks):
    image_path = test_image_paths[i]
    image = cv2.imread(image_path)
    print("Test Image:")
    cv2_imshow(image)
    print("Predicted Mask:")
    cv2_imshow(mask)

# %%
##########validation folder#########
import cv2
import numpy as np
from glob import glob
import os
from google.colab.patches import cv2_imshow
import tensorflow as tf

def preprocess_test_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (256, 256))
    image = image.astype(np.float32) / 255.0
    return image

def preprocess_test_mask(mask_path):
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (256, 256))
    mask = mask.astype(np.float32) / 255.0
    mask = np.expand_dims(mask, axis=-1)
    return mask

def postprocess_mask(mask):
    mask = cv2.resize(mask, (256, 256))
    mask=mask>0.5

    #mask = np.argmax(mask, axis=-1)
    mask = np.squeeze(mask)
    mask = mask.astype(np.uint8) * 255
    mask = np.concatenate([1 - mask, mask], axis=-1)
    return mask

def predict_test_images(model, test_image_paths, test_mask_paths):
    predicted_masks = []
    for image_path, mask_path in zip(test_image_paths, test_mask_paths):
        image = preprocess_test_image(image_path)
        mask = preprocess_test_mask(mask_path)
        predicted_mask = model.predict(np.expand_dims(image, axis=0))[0]
        predicted_mask = postprocess_mask(predicted_mask)
        predicted_masks.append(predicted_mask)
    return predicted_masks

# Specify the path to your test folder containing images and masks
test_folder = "/content/drive/MyDrive/Foot Ulcer Segmentation Challenge/validation"

test_image_paths = sorted(glob(os.path.join(test_folder, "images", "*.png")))
test_mask_paths = sorted(glob(os.path.join(test_folder, "labels", "*.png")))

# Load the trained model
model_path = "/content/drive/MyDrive/Foot Ulcer Segmentation Challenge/model.h5"
model = tf.keras.models.load_model(model_path, custom_objects={'dice_loss': dice_loss, 'focal_loss': focal_loss, 'bce_dice_loss': bce_dice_loss, 'dice_coef': dice_coef, 'iou': iou})

# Generate predicted masks for test images
predicted_masks = predict_test_images(model, test_image_paths, test_mask_paths)

# Display the test images, corresponding masks, and predicted masks
for i in range(len(test_image_paths)):
    image_path = test_image_paths[i]
    mask_path = test_mask_paths[i]
    predicted_mask = predicted_masks[i]

    test_image = cv2.imread(image_path)
    test_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    print("Test Image:")
    cv2_imshow(test_image)
    print("Corresponding Mask:")
    cv2_imshow(test_mask)
    print("Predicted Mask:")
    cv2_imshow(predicted_mask)
